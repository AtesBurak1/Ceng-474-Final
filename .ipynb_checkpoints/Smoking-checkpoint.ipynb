# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

pyhsical_devices = tf.config.list_physical_devices("GPU")
print(pyhsical_devices)
tf.config.experimental.set_memory_growth(pyhsical_devices[0],True)
df = pd.read_csv("smoking.csv")
pd.set_option('display.max_columns', None)
##missing_count = df.isna().sum()  0
##print(missing_count)   0

#No need id because it is unique to everyone
df = df.drop(['ID'], axis = 1)
## No need for oral column since every value is 1
df = df.drop(['oral'], axis = 1)
## Encode
df['gender'] = df['gender'].replace({'F': 1, 'M': 0})
df['tartar'] = df['tartar'].replace({'Y': 1, 'N': 0})
## Combine left and right eyesight and hearing
df['eyesight'] = df[['eyesight(left)', 'eyesight(right)']].mean(axis=1)
df['hearing'] = df[['hearing(left)', 'hearing(right)']].mean(axis=1)
df = df.drop(['eyesight(left)', 'eyesight(right)','hearing(left)', 'hearing(right)'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 from sklearn.preprocessing import RobustScaler
#       4 from sklearn.preprocessing import MinMaxScaler
# ----> 5 import tensorflow as tf
#       7 pyhsical_devices = tf.config.list_physical_devices("GPU")
#       8 print(pyhsical_devices)
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:51
#      49 from ._api.v2 import autograph
#      50 from ._api.v2 import bitwise
# ---> 51 from ._api.v2 import compat
#      52 from ._api.v2 import config
#      53 from ._api.v2 import data
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\compat\__init__.py:37
#       3 """Compatibility functions.
#       4
#       5 The `tf.compat` module contains two sets of compatibility functions.
#    (...)
#      32
#      33 """
#      35 import sys as _sys
# ---> 37 from . import v1
# ...

# %%
#Describe data to look is there any outlayer values
df.describe()

# %%
#For get rid of outlayer values appyly lambda funcyion to dataframe
def quantile_handler(df, column_name):
  # get rid of the very big outlayers, we not used Q1, Q2 quantile beacuse in human test it could be important to have these level of symptoms
  upper = df[column_name].quantile(0.99)
  #print(upper) 
  df_temp = df[(df[column_name] <= upper)]
  return df_temp

outlayer_columns = ['fasting blood sugar', 'triglyceride', 'HDL', 'LDL', 'AST', 'ALT', 'Gtp']
before_quantile = df['AST'].count() #AST is a random column name
for column_names in outlayer_columns:
  df = quantile_handler(df, column_names)
after_quantile = df['AST'].count()

#Data loss
before_quantile - after_quantile

# %%
## Scale the data
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.describe() #Now we have more stable values
# Out:
#              gender           age    height(cm)    weight(kg)     waist(cm)  \
# count  51980.000000  51980.000000  51980.000000  51980.000000  51980.000000
# mean       0.371970     44.157657    164.577241     65.561755     81.777272
# std        0.483335     12.117475      9.225510     12.594014      9.133005
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%        0.000000     40.000000    160.000000     55.000000     75.500000
# 50%        0.000000     40.000000    165.000000     65.000000     81.700000
# 75%        1.000000     55.000000    170.000000     75.000000     88.000000
# max        1.000000     85.000000    190.000000    135.000000    129.000000
#
#            systolic    relaxation  fasting blood sugar   Cholesterol  \
# count  51980.000000  51980.000000         51980.000000  51980.000000
# mean     121.210543     75.780800            97.644710    195.256349
# std       13.557447      9.593252            14.816597     34.275444
# ...

# %%
Y = df['smoking']
X = df_scaled.drop(['smoking'], axis=1)
#Split data for feature selection

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from cuml.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.feature_selection import mutual_info_classif


# Lets find how many features are needed using a loop and 5 different feature selection method
feature_count = 12 # will go to 8
RFC = RandomForestClassifier(n_estimators=100)
model = {
  'RFE': {"accuracy": 0, "feature_count": 0},
  'chi2': {"accuracy": 0, "feature_count": 0},
  'Lasso': {"accuracy": 0, "feature_count": 0},
  'mutual': {"accuracy": 0, "feature_count": 0},
  'RFC': {"accuracy": 0, "feature_count": 0}
}
#Only lasso is applied once
lasso = Lasso(alpha=0.01)
lasso.fit(X, Y)

# Get feature which does not have coeffient 0
selected_features = X.columns[lasso.coef_ != 0]
X_lasso = X[selected_features]
X_train_lasso, X_test_lasso, y_train_lasoo, y_test_lasso = train_test_split(X, Y, test_size=0.3, random_state=42)
RFC.fit(X_train_lasso,y_train_lasoo)
y_pred_lasso = RFC.predict(X_test_lasso)
model['Lasso']['accuracy'] = accuracy_score(y_test_lasso,y_pred_lasso)
model['Lasso']['feature_count'] = X_lasso.shape[1]

# %%
def RFC_train_test_SelectKBest(method, feature_count,X,Y):
  k_best = SelectKBest(score_func=method, k=feature_count)
  X_selected = k_best.fit_transform(X, Y)
  X_train, X_test, y_train, y_test = train_test_split(X_selected, Y, test_size=0.3, random_state=42)
  RFC.fit(X_train, y_train)
  y_pred = RFC.predict(X_test)
  return accuracy_score(y_test,y_pred)


def RFC_train_test_RFE(feature_count,X,Y):
  # Recursive forward elemination
  model = RandomForestClassifier(n_estimators=100)
  rfe = RFE(model, n_features_to_select=feature_count)
  fit = rfe.fit(X,Y)
  
  selected_features = X.columns[fit.support_]
  X_selected = X[selected_features]
  X_train, X_test, y_train, y_test = train_test_split(X_selected, Y, test_size=0.3, random_state=42)
  RFC.fit(X_train, y_train)
  y_pred = RFC.predict(X_test)
  return accuracy_score(y_test,y_pred)


while feature_count > 8:
    chi_acc = RFC_train_test_SelectKBest(chi2, feature_count, X, Y)
    mutual_acc = RFC_train_test_SelectKBest(mutual_info_classif, feature_count, X, Y)

    if chi_acc > model['chi2']['accuracy']: #update dictionary if result is better
       model['chi2']['accuracy'] = chi_acc
       model['chi2']['feature_count'] = feature_count

    if mutual_acc > model['mutual']['accuracy']: #update dictionary if result is better
       model['mutual']['accuracy'] = mutual_acc
       model['mutual']['feature_count'] = feature_count   
    feature_count = feature_count - 1

# %%
feature_count = 18
while feature_count < 21:
   RFE_acc = RFC_train_test_RFE(feature_count, X, Y)
   if RFE_acc > model['RFE']['accuracy']: #update dictionary if result is better
       model['RFE']['accuracy'] = mutual_acc
       model['RFE']['feature_count'] = feature_count
  
   feature_count = feature_count + 1

# %%
def RFC_train_test_RFC(X,Y,feature_count):
  #RFC feature selection
  RFC.fit(X, Y)

  # Access feature importances
  feature_importances = RFC.feature_importances_

  # Sort the features
  sorted_feature_indices = feature_importances.argsort()[::-1]

  selected_feature_indices = sorted_feature_indices[:feature_count]
  
  # select specified features    
  X_selected = X.to_numpy()[:, selected_feature_indices]
  # Split the data into training and testing sets
  X_train, X_test, y_train, y_test = train_test_split(X_selected, Y, test_size=0.3, random_state=42)
  new_rfc = RandomForestClassifier()
  new_rfc.fit(X_train, y_train)
  y_pred = new_rfc.predict(X_test)
  return accuracy_score(y_test,y_pred)

feature_count = 15
while feature_count < 20:
    RFC_acc = RFC_train_test_RFC(X,Y,feature_count)
    if RFC_acc > model['RFC']['accuracy']:
       model['RFC']['accuracy'] = mutual_acc
       model['RFC']['feature_count'] = feature_count
    feature_count = feature_count +1
       
#This block runs 1-2 minutes!

# %%
best_method = None
best_accuracy = 0

for method, info in model.items():
    accuracy = info['accuracy']
    if accuracy > best_accuracy:
        best_method = method
        best_accuracy = accuracy

print(f"The best feature selection method is '{best_method}' with an accuracy of {best_accuracy:.4f} and feature count {model[best_method]['feature_count']}")
# Out:
# The best feature selection method is 'Lasso' with an accuracy of 0.8213 and feature count 5
